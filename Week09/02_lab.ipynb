# %% [markdown]
# # Lab 9.2 (Deadline Friday 22 March 23:59)
#
# - Upload your code to [Einstein](https://ca117.computing.dcu.ie/einstein/)
#   to have it verified.

# %% [markdown]
# ## Contact
#
# - In `contact_092.py` define a `Contact` class to model a contact.
# - A contact has three data attributes: `name`, `phone`, `email`.
# - When your class is correctly implemented, running the following program
# should produce the given output.

# %%
from contact_092 import Contact

def main():

    c = Contact('Sue', '085-6442378', 'sue@eircom.net')

    assert(c.name == 'Sue')
    assert(c.phone == '085-6442378')
    assert(c.email == 'sue@eircom.net')

    print(c)

if __name__ == '__main__':
    main()

# %% [markdown]
# ```text
# Sue 085-6442378 sue@eircom.net
# ```

# %%
# TODO: Develop the Contact class

class Contact:
    def __init__(self, name, phone, email):
        self.name = name
        self.phone = phone
        self.email = email
        
    def __str__(self) -> str:
        return '{} {} {}'.format(self.name, self.phone, self.email)

c = Contact('Sue', '085-6442378', 'sue@eircom.net')

assert(c.name == 'Sue')
assert(c.phone == '085-6442378')
assert(c.email == 'sue@eircom.net')

print(c)
# Out:
# Sue 085-6442378 sue@eircom.net

# %% [markdown]
# ## Contact list
#
# - In `contactlist_092.py` define a `Contactlist` class to model
#   a contact list.
# - Include in `contactlist_092.py` a copy of your `Contact` class
#   from the previous question.
# - A contact list has a single data attribute: `d`.
# - `d` is a dictionary that maps a name to the corresponding instance
#   of the `Contact` class.
# - The `Contactlist` class defines the following instance methods:
#   - `__init__()` initialises a new `Contactlist`
#   - `add()` : adds a new `Contact` to the contact list (or
#     updates an existing `Contact` if already present)
#   - `remove()` : removes a `Contact` from the contact list (no
#     effect if no such contact exists)
#   - `get()` : returns the `Contact` with the specified name
#     (or returns `None` if not in the contact list)
#   - `__str__()` : returns a string containing all contacts’ details
#     listed in increasing alphabetical name order (you might add each
#     contact’s details to a list and invoke join on that list in order
#     to build the output of this method)
# - Once your classes are correctly implemented, running the following
# program should produce the given output.

# %%
from contactlist_092 import Contact, Contactlist


class Contactlist:
    def __init__(self):
        self.d = {}
        
    def add(self, c):
        self.d[c.name] = c

    def remove(self, name):
        if name in self.d:
            del(self.d(name))
        
    def get(self, name):
        return self.d.get(name)

    def __str__(self):
        lines = []
        for k, v in self.d.items():
            lines.append(''.format(v))
        return '\n'.join(lines.sort())

def main():
    clist = Contactlist()

    c1 = Contact('Sue', '085-6442378', 'sue@eircom.net')
    clist.add(c1)

    c2 = Contact('Jimmy', '086-1223277', 'james@apple.com')
    clist.add(c2)

    c3 = Contact('Wendy', '086-9112645', 'wendy@physics.dcu.ie')
    clist.add(c3)

    c = clist.get('Wendy')
    assert(c is c3)

    clist.remove('Wendy')
    c = clist.get('Wendy')
    assert(c is None)

    c4 = Contact('Abbey', '087-7586344', 'abbey@gmail.com')
    clist.add(c4)

    print(clist)

if __name__ == '__main__':
    main()

# %% [markdown]
# ```text
# Contact list
# ------------
# Abbey 087-7586344 abbey@gmail.com
# Jimmy 086-1223277 james@apple.com
# Sue 085-6442378 sue@eircom.net
# ```

# %%
# TODO: Develop the ContactList class

# clist = Contactlist()

# c1 = Contact('Sue', '085-6442378', 'sue@eircom.net')
# clist.add(c1)

# c2 = Contact('Jimmy', '086-1223277', 'james@apple.com')
# clist.add(c2)

# c3 = Contact('Wendy', '086-9112645', 'wendy@physics.dcu.ie')
# clist.add(c3)

# c = clist.get('Wendy')
# assert(c is c3)

# clist.remove('Wendy')
# c = clist.get('Wendy')
# assert(c is None)

# c4 = Contact('Abbey', '087-7586344', 'abbey@gmail.com')
# clist.add(c4)

# print(clist)

# %% [markdown]
# ## Meeting
#
# - In `meeting_092.py` define a `Meeting` class to model a meeting.
# - A meeting has three data attributes: a starting hour, a starting minute
#   and a duration.
# - When your class is correctly implemented, running the following program
# should produce the given output.

# %%
from meeting_092 import Meeting

def main():

    m = Meeting(9, 5, 30)

    assert(m.hour == 9)
    assert(m.minute == 5)
    assert(m.duration == 30)

    print(m)

if __name__ == '__main__':
    main()

# %% [markdown]
# ```text
# 09:05 (30 minutes)
# ```

# %%
# TODO: Develop the Meeting class

# m = Meeting(9, 5, 30)

# assert(m.hour == 9)
# assert(m.minute == 5)
# assert(m.duration == 30)

# print(m)
